# %% [markdown]
# <a href="https://colab.research.google.com/github/lcbjrrr/ProgWdata/blob/main/CSC116_5_Box_Quartile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quartiles and Boxplot

# %% [markdown]
# Quartiles and boxplots are valuable tools in descriptive statistics. Quartiles divide a dataset into four equal parts, providing insight into the data's distribution. A boxplot visually represents this information, using quartiles to display the spread, median, and potential outliers. These tools are used to summarize data distribution, identify outliers, compare distributions across different groups, and understand the variability within a dataset, particularly through the interquartile range which highlights the spread of the central 50% of the data.

# %% [markdown]
# ## Quartiles

# %% [markdown]
# Quartiles are specific percentiles that divide a dataset into four equal parts: the first quartile (Q1) is the 25th percentile, the second quartile (Q2) is the 50th percentile (which is also the median), and the third quartile (Q3) is the 75th percentile. Percentiles, in general, indicate the value below which a given percentage of observations in a dataset falls.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/ProgWdata/refs/heads/main/grades_final.csv')
df.head(3)
# Out:
#   Course Student  AP1  AP2  AP3  Grade Score
# 0    ADM    Finn   90   90   90     91     A
# 1    ADM    Jack   60   40  100     61     D
# 2    LAW     Leo   40   30   40     36     E

# %%
print(df["Grade"].describe())
# Out:
# count    12.000000
# mean     71.583333
# std      19.602682
# min      36.000000
# 25%      59.250000
# 50%      75.000000
# 75%      86.750000
# max      97.000000
# Name: Grade, dtype: float64

# %% [markdown]
# ## Boxplot

# %% [markdown]
# A boxplot is a graphical representation of data distribution that shows quartiles, median, and potential outliers. The box represents the interquartile range (Q1 to Q3), the line inside is the median (Q2), and the whiskers extend to show the data range, excluding outliers.

# %%
import seaborn as sns
sns.boxplot(df["Grade"]).set(**{})
# Out:
# []

# %%
sns.boxplot(data=df,y="Grade")
# Out:
# <Axes: ylabel='Grade'>

# %%
sns.boxplot(data=df,y="Grade",x="Course")
# Out:
# <Axes: xlabel='Course', ylabel='Grade'>

# %% [markdown]
# Quartiles divide data into four equal parts, with the first quartile (Q1) at the 25th percentile, the second (Q2) as the median, and the third (Q3) at the 75th percentile. The Interquartile Range (IQR) is the spread of the middle 50% of the data, calculated as $Q3 - Q1$$Q3 - Q1$. Boxplot limits, or fences, are used to identify potential outliers and are determined by $Q1 - 1.5 \times IQR$$Q1 - 1.5 \times IQR$ for the lower limit and $Q3 + 1.5 \times IQR$$Q3 + 1.5 \times IQR$ for the upper limit.
#
# ![](https://docs.oracle.com/en/cloud/saas/tax-reporting-cloud/ustrc/img/insights_iqr_example.jpg)
#
# Additional information: [IQR - Inter Quatile Range](https://builtin.com/articles/1-5-iqr-rule)

# %%
sns.boxplot(data=df,y="Grade",x="Course",hue='Score')
# Out:
# <Axes: xlabel='Course', ylabel='Grade'>
