# %% [markdown]
# <a href="https://colab.research.google.com/github/lcbjrrr/ProgWdata/blob/main/CSC116_7_Corr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Correlation Analysis

# %% [markdown]
# ## Scatterplot

# %% [markdown]
# A scatterplot is a graphical representation that uses dots to display the relationship between two different numerical variables, helping to identify patterns or correlations.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/ProgWdata/refs/heads/main/autos.csv')
df.head(2)
# Out:
#    age  gender  premium
# 0   23       1      333
# 1   24       0      320

# %%
import seaborn as sns
sns.scatterplot(x = df["age"], y = df["premium"], hue = None).set(**{})
# Out:
# []

# %% [markdown]
# ## Correlation

# %% [markdown]
# A correlation matrix shows the pairwise correlations between numerical columns in the DataFrame. The values in the matrix range from -1 to 1:
#
# - **1**: Perfect positive correlation (as one variable increases, the other increases proportionally).
# - **-1**: Perfect negative correlation (as one variable increases, the other decreases proportionally).
# - **0**: No correlation (no linear relationship between the variables).
#
# By analyzing the correlation matrix, you can identify relationships between variables, which can be helpful for feature engineering, model selection, and understanding the underlying patterns in your data.

# %%
df.corr()
# Out:
#               age    gender   premium
# age      1.000000 -0.066089 -0.979075
# gender  -0.066089  1.000000  0.189203
# premium -0.979075  0.189203  1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
#  A pairplot is a powerful visualization tool that shows pairwise relationships between numerical variables in a dataset. It creates a matrix of scatter plots, where each plot represents the relationship between two variables. The diagonal of the matrix often displays histograms or kernel density plots to visualize the distribution of each variable

# %%
sns.pairplot(df)

# %% [markdown]
# ## Linear Model

# %% [markdown]
# Linear models are statistical models that assume a linear relationship between the dependent variable and one or more independent variables. The sns.lmplot function in Seaborn is used to draw a scatter plot with a regression line, which visually represents this linear relationship, and can also display confidence intervals around the regression line.

# %%
sns.lmplot(data=df, x="age", y="premium")
